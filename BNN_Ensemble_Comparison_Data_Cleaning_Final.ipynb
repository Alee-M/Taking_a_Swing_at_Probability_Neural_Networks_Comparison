# %% [markdown]
# <a href="https://colab.research.google.com/github/Alee-M/Taking_a_Swing_at_Probability_Neural_Networks_Comparison/blob/main/BNN_Ensemble_Comparison_Data_Cleaning_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Setup

# %%
#Connect to Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Import necessary packages
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
#Set Directory
#dir = '/content/drive/MyDrive/Research/Baseball/Data/Final Data/'
dir = '/content/drive/MyDrive/Baseball/Data/Final Data/'

# %% [markdown]
# ###2017 Data

# %% [markdown]
# Start: 3/29/2017
# ASG: 7/11/2017
# EOS: 10/2/2017

# %%
#ASG data represents SO/PA at the midpoint of the baseball season (the All-Star Break)
ASG2017 = pd.read_csv(dir + '2017_Start_to_ASG_160.csv') #Load in CSV (direct export from FanGraphs)
ASG2017 = ASG2017[['playerId','SO','PA']] #Remove unnecessary columns
ASG2017
# Out:
#      playerId  SO   PA
# 0         393  37  286
# 1         589  66  313
# 2         785  67  322
# 3         791  42  326
# 4        1159  42  196
# ..        ...  ..  ...
# 287     17901  56  354
# 288     17919  61  203
# 289     18314  77  335
# 290     18721  28  229
# 291     19198  37  308
#
# [292 rows x 3 columns]

# %%
#EOS data represents SO/PA with full season data
EOS2017 = pd.read_csv(dir + '2017_Start_to_EOS_160.csv') #Load in CSV (direct export from FanGraphs)
EOS2017 = EOS2017[['playerId','SO','PA']] #Remove unnecesaary columns
EOS2017['SO/PA'] = EOS2017['SO']/EOS2017['PA'] #Calculate strikeout rate
EOS2017=EOS2017.drop(columns=['PA','SO']) #Drop columns used for calculation
EOS2017
# Out:
#      playerId     SO/PA
# 0         393  0.144828
# 1         589  0.200393
# 2         639  0.133676
# 3         785  0.217014
# 4         791  0.120861
# ..        ...       ...
# 381     18015  0.279910
# 382     18314  0.217786
# 383     18718  0.192469
# 384     18721  0.150235
# 385     19198  0.109929
#
# [386 rows x 2 columns]

# %%
#Create merged data for 2017
data2017 = pd.merge(ASG2017, EOS2017, on=['playerId'], how='inner') #Merge data at All-Star_Break with data at End of Season, inner join -> only players in both datasets
data2017=data2017.dropna() #Drop rows with blank values
data2017
# Out:
#      playerId  SO   PA     SO/PA
# 0         393  37  286  0.144828
# 1         589  66  313  0.200393
# 2         785  67  322  0.217014
# 3         791  42  326  0.120861
# 4        1159  42  196  0.192529
# ..        ...  ..  ...       ...
# 287     17901  56  354  0.170213
# 288     17919  61  203  0.312349
# 289     18314  77  335  0.217786
# 290     18721  28  229  0.150235
# 291     19198  37  308  0.109929
#
# [292 rows x 4 columns]

# %% [markdown]
# ### 2018 Data

# %% [markdown]
# Start: 3/29/2018
# ASG: 7/17/2018
# EOS: 10/1/2018

# %%
#ASG data represents SO/PA at the midpoint of the baseball season (the All-Star Break)
ASG2018 = pd.read_csv(dir + '2018_Start_to_ASG_160.csv') #Load in CSV (direct export from FanGraphs)
ASG2018 = ASG2018[['playerId','SO','PA']] #Remove unnecessary columns
ASG2018
# Out:
#      playerId  SO   PA
# 0         393  32  326
# 1         639  55  261
# 2         785  58  260
# 3        1177  52  368
# 4        1433  61  315
# ..        ...  ..  ...
# 291     18314  79  327
# 292     18401  56  184
# 293     18721  46  244
# 294     19198  34  335
# 295     20123  41  209
#
# [296 rows x 3 columns]

# %%
#EOS data represents SO/PA with full season data
EOS2018 = pd.read_csv(dir + '2018_Start_to_EOS_160.csv') #Load in CSV (direct export from FanGraphs)
EOS2018 = EOS2018[['playerId','SO','PA']] #Remove unnecesaary columns
EOS2018['SO/PA'] = EOS2018['SO']/EOS2018['PA'] #Calculate strikeout rate
EOS2018=EOS2018.drop(columns=['PA','SO']) #Drop columns used for calculation
EOS2018
# Out:
#      playerId     SO/PA
# 0         393  0.096457
# 1         639  0.199584
# 2         785  0.237288
# 3        1177  0.130522
# 4        1433  0.192308
# ..        ...       ...
# 377     18721  0.154303
# 378     19198  0.109948
# 379     19238  0.224335
# 380     19755  0.277929
# 381     20123  0.200405
#
# [382 rows x 2 columns]

# %%
#Create merged data for 2018
data2018 = pd.merge(ASG2018, EOS2018, on=['playerId'], how='inner') #Merge data at All-Star_Break with data at End of Season, inner join -> only players in both datasets
data2018=data2018.dropna() #Drop rows with blank values
data2018
# Out:
#      playerId  SO   PA     SO/PA
# 0         393  32  326  0.096457
# 1         639  55  261  0.199584
# 2         785  58  260  0.237288
# 3        1177  52  368  0.130522
# 4        1433  61  315  0.192308
# ..        ...  ..  ...       ...
# 291     18314  79  327  0.228893
# 292     18401  56  184  0.252567
# 293     18721  46  244  0.154303
# 294     19198  34  335  0.109948
# 295     20123  41  209  0.200405
#
# [296 rows x 4 columns]

# %% [markdown]
# ### 2019 Data

# %% [markdown]
# Start: 3/20/2019
# ASG: 7/9/2019
# EOS: 9/29/2019

# %%
#ASG data represents SO/PA at the midpoint of the baseball season (the All-Star Break)
ASG2019 = pd.read_csv(dir + '2019_Start_to_ASG_160.csv') #Load in CSV (direct export from FanGraphs)
ASG2019 = ASG2019[['playerId','SO','PA']] #Remove unnecessary columns
ASG2019
# Out:
#      playerId  SO   PA
# 0         785  46  247
# 1        1177  35  295
# 2        1433  44  281
# 3        1744  64  319
# 4        2136  72  324
# ..        ...  ..  ...
# 289     19611  47  253
# 290     19709  67  234
# 291     19755  53  218
# 292     19858  44  202
# 293     20123  73  342
#
# [294 rows x 3 columns]

# %%
#EOS data represents SO/PA with full season data
EOS2019 = pd.read_csv(dir + '2019_Start_to_EOS_160.csv') #Load in CSV (direct export from FanGraphs)
EOS2019 = EOS2019[['playerId','SO','PA']] #Remove unnecesaary columns
EOS2019['SO/PA'] = EOS2019['SO']/EOS2019['PA'] #Calculate strikeout rate
EOS2019=EOS2019.drop(columns=['PA','SO']) #Drop columns used for calculation
EOS2019
# Out:
#      playerId     SO/PA
# 0         785  0.212425
# 1        1177  0.124771
# 2        1433  0.131679
# 3        1744  0.196721
# 4        2136  0.205674
# ..        ...       ...
# 396     19755  0.258824
# 397     19858  0.229064
# 398     19878  0.247934
# 399     20003  0.307471
# 400     20123  0.200303
#
# [401 rows x 2 columns]

# %%
#Create merged data for 2019
data2019 = pd.merge(ASG2019, EOS2019, on=['playerId'], how='inner') #Merge data at All-Star_Break with data at End of Season, inner join -> only players in both datasets
data2019=data2019.dropna() #Drop rows with blank values
data2019
# Out:
#      playerId  SO   PA     SO/PA
# 0         785  46  247  0.212425
# 1        1177  35  295  0.124771
# 2        1433  44  281  0.131679
# 3        1744  64  319  0.196721
# 4        2136  72  324  0.205674
# ..        ...  ..  ...       ...
# 289     19611  47  253  0.177043
# 290     19709  67  234  0.295699
# 291     19755  53  218  0.258824
# 292     19858  44  202  0.229064
# 293     20123  73  342  0.200303
#
# [294 rows x 4 columns]

# %% [markdown]
# ####Skipping 2020 as this was not a full traditional MLB season

# %% [markdown]
# ### 2021 Data

# %% [markdown]
# Start: 4/1/21
# ASG: 7/13/21
# EOS: 10/3/21

# %%
#ASG data represents SO/PA at the midpoint of the baseball season (the All-Star Break)
ASG2021 = pd.read_csv(dir + '2021_Start_to_ASG_160.csv') #Load in CSV (direct export from FanGraphs)
ASG2021 = ASG2021[['playerId','SO','PA']] #Remove unnecessary columns
ASG2021
# Out:
#      playerId  SO   PA
# 0        1177  29  208
# 1        1744  74  277
# 2        2136  53  329
# 3        2396  56  375
# 4        2434  57  318
# ..        ...  ..  ...
# 273     21523  70  316
# 274     21618  86  329
# 275     22168  67  239
# 276     26197  68  272
# 277     27506  47  201
#
# [278 rows x 3 columns]

# %%
#EOS data represents SO/PA with full season data
EOS2021 = pd.read_csv(dir + '2021_Start_to_EOS_160.csv') #Load in CSV (direct export from FanGraphs)
EOS2021 = EOS2021[['playerId','SO','PA']] #Remove unnecesaary columns
EOS2021['SO/PA'] = EOS2021['SO']/EOS2021['PA'] #Calculate strikeout rate
EOS2021=EOS2021.drop(columns=['PA','SO']) #Drop columns used for calculation
EOS2021
# Out:
#      playerId     SO/PA
# 0        1177  0.152027
# 1        1433  0.220859
# 2        1744  0.224335
# 3        2136  0.171004
# 4        2396  0.154780
# ..        ...       ...
# 395     24655  0.267327
# 396     26197  0.215352
# 397     27459  0.274809
# 398     27461  0.218579
# 399     27506  0.238255
#
# [400 rows x 2 columns]

# %%
#Create merged data for 2021
data2021 = pd.merge(ASG2021, EOS2021, on=['playerId'], how='inner') #Merge data at All-Star_Break with data at End of Season, inner join -> only players in both datasets
data2021=data2021.dropna() #Drop rows with blank values
data2021
# Out:
#      playerId  SO   PA     SO/PA
# 0        1177  29  208  0.152027
# 1        1744  74  277  0.224335
# 2        2136  53  329  0.171004
# 3        2396  56  375  0.154780
# 4        2434  57  318  0.215753
# ..        ...  ..  ...       ...
# 273     21523  70  316  0.223455
# 274     21618  86  329  0.266187
# 275     22168  67  239  0.264642
# 276     26197  68  272  0.215352
# 277     27506  47  201  0.238255
#
# [278 rows x 4 columns]

# %% [markdown]
# ### 2022 Data

# %% [markdown]
# Start: 4/7/2022
# ASG: 7/19/2022
# EOS: 10/5/2022

# %%
#ASG data represents SO/PA at the midpoint of the baseball season (the All-Star Break)
ASG2022 = pd.read_csv(dir + '2022_Start_to_ASG_160.csv') #Load in CSV (direct export from FanGraphs)
ASG2022 = ASG2022[['playerId','SO','PA']] #Remove unnecessary columns
ASG2022
# Out:
#      playerId  SO   PA
# 0        1177  31  173
# 1        1744  74  309
# 2        2136  72  286
# 3        2396  41  281
# 4        2434  78  351
# ..        ...  ..  ...
# 293     26294  43  220
# 294     27459  40  170
# 295     27465  76  298
# 296     27506  57  322
# 297     30116  57  211
#
# [298 rows x 3 columns]

# %%
#EOS data represents SO/PA with full season data
EOS2022 = pd.read_csv(dir + '2022_Start_to_EOS_160.csv') #Load in CSV (direct export from FanGraphs)
EOS2022 = EOS2022[['playerId','SO','PA']] #Remove unnecesaary columns
EOS2022['SO/PA'] = EOS2022['SO']/EOS2022['PA'] #Calculate strikeout rate
EOS2022=EOS2022.drop(columns=['PA','SO']) #Drop columns used for calculation
EOS2022
# Out:
#      playerId     SO/PA
# 0        1177  0.156695
# 1        1744  0.233256
# 2        2136  0.232653
# 3        2396  0.173913
# 4        2434  0.234714
# ..        ...       ...
# 400     27465  0.245050
# 401     27506  0.171821
# 402     27676  0.114094
# 403     27684  0.237113
# 404     30116  0.246637
#
# [405 rows x 2 columns]

# %%
#Create merged data for 2022
data2022 = pd.merge(ASG2022, EOS2022, on=['playerId'], how='inner') #Merge data at All-Star_Break with data at End of Season, inner join -> only players in both datasets
data2022=data2022.dropna() #Drop rows with blank values
data2022
# Out:
#      playerId  SO   PA     SO/PA
# 0        1177  31  173  0.156695
# 1        1744  74  309  0.233256
# 2        2136  72  286  0.232653
# 3        2396  41  281  0.173913
# 4        2434  78  351  0.234714
# ..        ...  ..  ...       ...
# 293     26294  43  220  0.190987
# 294     27459  40  170  0.259067
# 295     27465  76  298  0.245050
# 296     27506  57  322  0.171821
# 297     30116  57  211  0.246637
#
# [298 rows x 4 columns]

# %% [markdown]
# ### Merging All Data

# %%
#Make dataframe with all years
Full_data=pd.concat([data2017, data2018, data2019, data2021, data2022]) #Concatenate all previous dataframes
Full_data.rename(columns = {'SO/PA':'EOS_SO/PA'}, inplace = True) #Rename to differentiate stats
Full_data
# Out:
#      playerId  SO   PA  EOS_SO/PA
# 0         393  37  286   0.144828
# 1         589  66  313   0.200393
# 2         785  67  322   0.217014
# 3         791  42  326   0.120861
# 4        1159  42  196   0.192529
# ..        ...  ..  ...        ...
# 293     26294  43  220   0.190987
# 294     27459  40  170   0.259067
# 295     27465  76  298   0.245050
# 296     27506  57  322   0.171821
# 297     30116  57  211   0.246637
#
# [1458 rows x 4 columns]

# %% [markdown]
# ### Define Inputs and Outputs, Test/Train Split

# %%
#Define X and Y variables
x=Full_data[['playerId','SO','PA']] #Only variables for ASG SO/PA
y=Full_data[['playerId','EOS_SO/PA']] #End of Season SO/PA

# %%
#Test/Train Split
X_train, X_test, Y_train, Y_test = train_test_split(x, y)

# %%
X_test
# Out:
#      playerId  SO   PA
# 285     17901  71  405
# 259     19709  88  313
# 262     20332  40  204
# 150      9393  55  239
# 257     16578  50  296
# ..        ...  ..  ...
# 270     20454  90  283
# 279     22458  70  268
# 186     16252  70  375
# 55       4720  82  320
# 230     19470  72  399
#
# [365 rows x 3 columns]

# %%
Y_test
# Out:
#      playerId  EOS_SO/PA
# 285     17901   0.160363
# 259     19709   0.280220
# 262     20332   0.214286
# 150      9393   0.239782
# 257     16578   0.175793
# ..        ...        ...
# 270     20454   0.285996
# 279     22458   0.257511
# 186     16252   0.170279
# 55       4720   0.225256
# 230     19470   0.176190
#
# [365 rows x 2 columns]

# %% [markdown]
# ### Save/Export Full Dataset

# %%
#Export full dataframe
Full_data.to_csv('BaseballResearchFullDataNotCumulative_Spring26.csv')
#!cp BaseballResearchFullDataNotCumulative.csv "/content/drive/MyDrive/Research/Baseball/Data"
# !cp BaseballResearchFullDataNotCumulative_Spring26.csv "/content/drive/MyDrive/Baseball/Data"

# %%
#Save Test/Train Split
np.savez('Baseball_Full_Train2.npz', xTrain=X_train, yTrain=Y_train)
np.savez('Baseball_Full_Test2.npz', xTest=X_test, yTest=Y_test)
# !cp 'Baseball_Full_Train2.npz' "/content/drive/MyDrive/Baseball/Data"
# !cp 'Baseball_Full_Test2.npz' "/content/drive/MyDrive/Baseball/Data"
